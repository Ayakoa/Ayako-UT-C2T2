# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
print(digits.data)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
db_connection_str = 'mysql+pymysql://deepanalytics:Sqltask1234!@34.73.222.197/deepanalytics'

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
db_connection = create_engine(db_connection_str)

# %%
df = pd.read_sql('SELECT * FROM credit', con=db_connection)

# %%
df = df.drop_duplicates()

# %%
to_drop = ['MyUnknownColumn']
df.drop(to_drop, inplace=True, axis=1)

# %%
df = df.drop_duplicates()

# %%
import pandas_profiling
import numpy as np

# %%
df.to_csv('credit-one.csv', index=False)

# %%
df=pd.read_csv('credit-one.csv', skiprows=[0])

# %%
df.dropna()
# Out:
#       LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 0         20000  female   university        1  24     2     2    -1    -1
# 1        120000  female   university        2  26    -1     2     0     0
# 2         90000  female   university        2  34     0     0     0     0
# 3         50000  female   university        1  37     0     0     0     0
# 4         50000    male   university        1  57    -1     0    -1     0
# ...         ...     ...          ...      ...  ..   ...   ...   ...   ...
# 29961    220000    male  high school        1  39     0     0     0     0
# 29962    150000    male  high school        2  43    -1    -1    -1    -1
# 29963     30000    male   university        2  37     4     3     2    -1
# 29964     80000    male  high school        1  41     1    -1     0     0
# 29965     50000    male   university        1  46     0     0     0     0
#
#       PAY_5  ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3  \
# ...

# %%
df = df.fillna(value=np.nan)

# %%
df.fillna(value=np.nan, inplace=True)

# %%
df=pd.read_csv('credit-one.csv', skiprows=[0])
df.dropna()
# Out:
#       LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 0         20000  female   university        1  24     2     2    -1    -1
# 1        120000  female   university        2  26    -1     2     0     0
# 2         90000  female   university        2  34     0     0     0     0
# 3         50000  female   university        1  37     0     0     0     0
# 4         50000    male   university        1  57    -1     0    -1     0
# ...         ...     ...          ...      ...  ..   ...   ...   ...   ...
# 29961    220000    male  high school        1  39     0     0     0     0
# 29962    150000    male  high school        2  43    -1    -1    -1    -1
# 29963     30000    male   university        2  37     4     3     2    -1
# 29964     80000    male  high school        1  41     1    -1     0     0
# 29965     50000    male   university        1  46     0     0     0     0
#
#       PAY_5  ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3  \
# ...

# %%
df=pd.read_csv('credit-one.csv', skiprows=[0, 203, 204])
df.dropna()
# Out:
#        LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          20000  female   university         1   24      2      2     -1
# 1         120000  female   university         2   26     -1      2      0
# 2          90000  female   university         2   34      0      0      0
# 3          50000  female   university         1   37      0      0      0
# 4          50000    male   university         1   57     -1      0     -1
# ...          ...     ...          ...       ...  ...    ...    ...    ...
# 29959     220000    male  high school         1   39      0      0      0
# 29960     150000    male  high school         2   43     -1     -1     -1
# 29961      30000    male   university         2   37      4      3      2
# 29962      80000    male  high school         1   41      1     -1      0
# 29963      50000    male   university         1   46      0      0      0
#
#        PAY_4  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
df[['LIMIT_BAL','MARRIAGE','EDUCATION']].groupby ('MARRIAGE'). mean()
# Out:
#               LIMIT_BAL
# MARRIAGE
# 0         132962.962963
# 1         182151.432969
# 2         156379.056698
# 3          98080.495356

# %%
df = pd.get_dummies(df)

# %%
df.rename(columns = {"default payment next month_default": "Default","default payment next month_not default": "Not Default"})
# Out:
#        LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# 0          20000         1   24      2      2     -1     -1     -2     -2
# 1         120000         2   26     -1      2      0      0      0      2
# 2          90000         2   34      0      0      0      0      0      0
# 3          50000         1   37      0      0      0      0      0      0
# 4          50000         1   57     -1      0     -1      0      0      0
# ...          ...       ...  ...    ...    ...    ...    ...    ...    ...
# 29959     220000         1   39      0      0      0      0      0      0
# 29960     150000         2   43     -1     -1     -1     -1      0      0
# 29961      30000         2   37      4      3      2     -1      0      0
# 29962      80000         1   41      1     -1      0      0      0     -1
# 29963      50000         1   46      0      0      0      0      0      0
#
#        BILL_AMT1  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
df = df.rename(columns = {"default payment next month_default": "Default","default payment next month_not default": "Not Default"})

# %%
df[['LIMIT_BAL','MARRIAGE','Default','Not Default']].groupby ('MARRIAGE'). mean()
# Out:
#               LIMIT_BAL   Default  Not Default
# MARRIAGE
# 0         132962.962963  0.092593     0.907407
# 1         182151.432969  0.234626     0.765374
# 2         156379.056698  0.209483     0.790517
# 3          98080.495356  0.260062     0.739938

# %%
y = df['LIMIT_BAL']

# %%
X = df[{'MARRIAGE','Default','Not Default'}]

# %%
def get_group(x):
    if x <= 80000 and x > 0:
        return 'A - 0-80000'
    if x <= 150000 and x > 80000:
        return 'B - 80000-150000'
    if x <= 300000 and x > 150000:
        return 'C - 150000-300000'
    if x <= 500000 and x > 300000:
        return 'D - 300000- 500000'
    if x <= 10000000 and x > 500000:
        return 'E - 500000-10000000'
    else:
        return 'LIMIT_BAL',x

# %%
LIMIT_BAL_df = []

for i in df['LIMIT_BAL']:
    LIMIT_BAL_df.append(get_group(i))

# %%
df['LIMIT_BAL'] = LIMIT_BAL_df

# %%
df[['MARRIAGE','Default','Not Default', 'LIMIT_BAL' ]].groupby('LIMIT_BAL').mean()
# Out:
#                      MARRIAGE   Default  Not Default
# LIMIT_BAL
# A - 0-80000          1.616974  0.300658     0.699342
# B - 80000-150000     1.569104  0.225639     0.774361
# C - 150000-300000    1.505597  0.168569     0.831431
# D - 300000- 500000   1.466084  0.133134     0.866866
# E - 500000-10000000  1.509709  0.111650     0.888350

# %%
def get_group(x):
    if x <= 80000 and x > 0:
        return '0-80000'
    if x <= 150000 and x > 80000:
        return '80000-150000'
    if x <= 300000 and x > 150000:
        return '150000-300000'
    if x <= 500000 and x > 300000:
        return '300000- 500000'
    if x <= 10000000 and x > 500000:
        return '500000-10000000'
    else:
        return 'LIMIT_BAL',x

# %%
df[['MARRIAGE','Default','Not Default', 'LIMIT_BAL' ]].groupby('LIMIT_BAL').mean()
# Out:
#                      MARRIAGE   Default  Not Default
# LIMIT_BAL
# A - 0-80000          1.616974  0.300658     0.699342
# B - 80000-150000     1.569104  0.225639     0.774361
# C - 150000-300000    1.505597  0.168569     0.831431
# D - 300000- 500000   1.466084  0.133134     0.866866
# E - 500000-10000000  1.509709  0.111650     0.888350

# %%
df.describe()
# Out:
#            MARRIAGE           AGE         PAY_0         PAY_2         PAY_3  \
# count  29964.000000  29964.000000  29964.000000  29964.000000  29964.000000
# mean       1.551862     35.488119     -0.016753     -0.131858     -0.164464
# std        0.521999      9.219577      1.123511      1.196341      1.195832
# min        0.000000     21.000000     -2.000000     -2.000000     -2.000000
# 25%        1.000000     28.000000     -1.000000     -1.000000     -1.000000
# 50%        2.000000     34.000000      0.000000      0.000000      0.000000
# 75%        2.000000     41.000000      0.000000      0.000000      0.000000
# max        3.000000     79.000000      8.000000      8.000000      8.000000
#
#               PAY_4         PAY_5         PAY_6      BILL_AMT1      BILL_AMT2  \
# count  29964.000000  29964.000000  29964.000000   29964.000000   29964.000000
# mean      -0.218929     -0.264517     -0.289514   51283.816079   49237.098418
# ...

# %%
df.head()
# Out:
#           LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# 0       A - 0-80000         1   24      2      2     -1     -1     -2     -2
# 1  B - 80000-150000         2   26     -1      2      0      0      0      2
# 2  B - 80000-150000         2   34      0      0      0      0      0      0
# 3       A - 0-80000         1   37      0      0      0      0      0      0
# 4       A - 0-80000         1   57     -1      0     -1      0      0      0
#
#    BILL_AMT1  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# 0       3913  ...         0         0           1         0
# 1       2682  ...         0      2000           1         0
# 2      29239  ...      1000      5000           1         0
# 3      46990  ...      1069      1000           1         0
# 4       8617  ...       689       679           0         1
#
#    EDUCATION_graduate school  EDUCATION_high school  EDUCATION_other  \
# ...

# %%
plt.scatter(x=df['Not Default'],y=df['LIMIT_BAL'], alpha=0.1)

# %%
plt.scatter(x=df['SEX_female'],y=df['LIMIT_BAL'], alpha=1)

# %%
pd.set_option("display.precision", 1)

# %%
df[['MARRIAGE','AGE','EDUCATION_university', 'Default','Not Default','SEX_female','SEX_male', 'LIMIT_BAL' ]].groupby('LIMIT_BAL').mean()
# Out:
#                      MARRIAGE   AGE  EDUCATION_university  \
# LIMIT_BAL
# A - 0-80000               1.6  34.3                   0.5
# B - 80000-150000          1.6  34.8                   0.5
# C - 150000-300000         1.5  36.3                   0.4
# D - 300000- 500000        1.5  37.6                   0.4
# E - 500000-10000000       1.5  39.2                   0.3
#
#                      EDUCATION_high school  Default  Not Default  SEX_female  \
# LIMIT_BAL
# A - 0-80000                        2.3e-01      0.3          0.7         0.6
# B - 80000-150000                   1.7e-01      0.2          0.8         0.7
# C - 150000-300000                  1.2e-01      0.2          0.8         0.6
# D - 300000- 500000                 9.2e-02      0.1          0.9         0.6
# E - 500000-10000000                1.2e-01      0.1          0.9         0.6
#
#                      SEX_male
# LIMIT_BAL
# A - 0-80000               0.4
# B - 80000-150000          0.3
# ...

# %%
df[['MARRIAGE','AGE','EDUCATION_university', 'Default','Not Default','SEX_female','SEX_male', 'LIMIT_BAL' ]].groupby('Default').mean()
#1=dault #0 = not
# Out:
#          MARRIAGE   AGE  EDUCATION_university  Not Default  SEX_female  \
# Default
# 0             1.6  35.4                   0.5          1.0         0.6
# 1             1.5  35.7                   0.5          0.0         0.6
#
#          SEX_male
# Default
# 0             0.4
# 1             0.4

# %%
df[['MARRIAGE','AGE','EDUCATION_university', 'Default','Not Default','SEX_female','SEX_male', 'LIMIT_BAL' ]].groupby('Not Default').mean()
# Out:
#              MARRIAGE   AGE  EDUCATION_university  Default  SEX_female  \
# Not Default
# 0                 1.5  35.7                   0.5      1.0         0.6
# 1                 1.6  35.4                   0.5      0.0         0.6
#
#              SEX_male
# Not Default
# 0                 0.4
# 1                 0.4
