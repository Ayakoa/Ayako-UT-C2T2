# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
db_connection_str = 'mysql+pymysql://deepanalytics:Sqltask1234!@34.73.222.197/deepanalytics'

# %%
db_connection = create_engine(db_connection_str)

# %%
df = pd.read_sql('SELECT * FROM credit', con=db_connection)

# %%
df = df.drop_duplicates()

# %%
to_drop = ['MyUnknownColumn']
df.drop(to_drop, inplace=True, axis=1)

# %%
import pandas_profiling
import numpy as np

# %%
import pandas_profiling

# %%
df.to_csv('credit-one.csv', index=False)

# %%
df=pd.read_csv('credit-one.csv', skiprows=[0])

# %%
header = df.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
X = df.iloc[:,0:23]
print('Summary of feature sample')
X.head()
# Out:
# Summary of feature sample
#   LIMIT_BAL     SEX   EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4 PAY_5  \
# 0     20000  female  university        1  24     2     2    -1    -1    -2
# 1    120000  female  university        2  26    -1     2     0     0     0
# 2     90000  female  university        2  34     0     0     0     0     0
# 3     50000  female  university        1  37     0     0     0     0     0
# 4     50000    male  university        1  57    -1     0    -1     0     0
#
#    ... BILL_AMT3 BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3  \
# 0  ...       689         0         0         0        0      689        0
# 1  ...      2682      3272      3455      3261        0     1000     1000
# 2  ...     13559     14331     14948     15549     1518     1500     1000
# 3  ...     49291     28314     28959     29547     2000     2019     1200
# 4  ...     35835     20940     19146     19131     2000    36681    10000
#
#   PAY_AMT4 PAY_AMT5 PAY_AMT6
# ...

# %%
df.dropna()
# Out:
#       LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 0         20000  female   university        1  24     2     2    -1    -1
# 1        120000  female   university        2  26    -1     2     0     0
# 2         90000  female   university        2  34     0     0     0     0
# 3         50000  female   university        1  37     0     0     0     0
# 4         50000    male   university        1  57    -1     0    -1     0
# ...         ...     ...          ...      ...  ..   ...   ...   ...   ...
# 29996    220000    male  high school        1  39     0     0     0     0
# 29997    150000    male  high school        2  43    -1    -1    -1    -1
# 29998     30000    male   university        2  37     4     3     2    -1
# 29999     80000    male  high school        1  41     1    -1     0     0
# 30000     50000    male   university        1  46     0     0     0     0
#
#       PAY_5  ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3  \
# ...

# %%
df = df.fillna(value=np.nan)

# %%
df.fillna(value=np.nan, inplace=True)

# %%
df=pd.read_csv('credit-one.csv', skiprows=[0])
df.dropna()
# Out:
#       LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 0         20000  female   university        1  24     2     2    -1    -1
# 1        120000  female   university        2  26    -1     2     0     0
# 2         90000  female   university        2  34     0     0     0     0
# 3         50000  female   university        1  37     0     0     0     0
# 4         50000    male   university        1  57    -1     0    -1     0
# ...         ...     ...          ...      ...  ..   ...   ...   ...   ...
# 29996    220000    male  high school        1  39     0     0     0     0
# 29997    150000    male  high school        2  43    -1    -1    -1    -1
# 29998     30000    male   university        2  37     4     3     2    -1
# 29999     80000    male  high school        1  41     1    -1     0     0
# 30000     50000    male   university        1  46     0     0     0     0
#
#       PAY_5  ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30001 non-null  object
#  1   SEX                         30001 non-null  object
#  2   EDUCATION                   30001 non-null  object
#  3   MARRIAGE                    30001 non-null  object
#  4   AGE                         30001 non-null  object
#  5   PAY_0                       30001 non-null  object
#  6   PAY_2                       30001 non-null  object
#  7   PAY_3                       30001 non-null  object
#  8   PAY_4                       30001 non-null  object
#  9   PAY_5                       30001 non-null  object
#  10  PAY_6                       30001 non-null  object
#  11  BILL_AMT1                   30001 non-null  object
#  12  BILL_AMT2                   30001 non-null  object
# ...

# %%
df = pd.read_sql('SELECT * FROM credit', con=db_connection)
count = 0
for i in df['X1']:
    count+=1
    try:
        int(i)
    except:
        print(f"row {count} failed to convert to an integer")
# Out:
# row 1 failed to convert to an integer
# row 203 failed to convert to an integer
# row 204 failed to convert to an integer

# %%
df=pd.read_csv('credit-one.csv', skiprows=[0, 203, 204])
df.dropna()
# Out:
#        LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          20000  female   university         1   24      2      2     -1
# 1         120000  female   university         2   26     -1      2      0
# 2          90000  female   university         2   34      0      0      0
# 3          50000  female   university         1   37      0      0      0
# 4          50000    male   university         1   57     -1      0     -1
# ...          ...     ...          ...       ...  ...    ...    ...    ...
# 29994     220000    male  high school         1   39      0      0      0
# 29995     150000    male  high school         2   43     -1     -1     -1
# 29996      30000    male   university         2   37      4      3      2
# 29997      80000    male  high school         1   41      1     -1      0
# 29998      50000    male   university         1   46      0      0      0
#
#        PAY_4  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   29999 non-null  int64
#  1   SEX                         29999 non-null  object
#  2   EDUCATION                   29999 non-null  object
#  3   MARRIAGE                    29999 non-null  int64
#  4   AGE                         29999 non-null  int64
#  5   PAY_0                       29999 non-null  int64
#  6   PAY_2                       29999 non-null  int64
#  7   PAY_3                       29999 non-null  int64
#  8   PAY_4                       29999 non-null  int64
#  9   PAY_5                       29999 non-null  int64
#  10  PAY_6                       29999 non-null  int64
#  11  BILL_AMT1                   29999 non-null  int64
#  12  BILL_AMT2                   29999 non-null  int64
# ...

# %%
df['AGE'].mean()
# Out:
# 35.48564952165072

# %%
df.dtypes
# Out:
# LIMIT_BAL                      int64
# SEX                           object
# EDUCATION                     object
# MARRIAGE                       int64
# AGE                            int64
# PAY_0                          int64
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month    object
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
header = df.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df[['LIMIT_BAL','MARRIAGE' ]].groupby ('MARRIAGE'). mean()
# Out:
#               LIMIT_BAL
# MARRIAGE
# 0         132962.962963
# 1         182200.893184
# 2         156414.688968
# 3          98080.495356

# %%
df['LIMIT_BAL'].plot(kind='hist')

# %%
pd.cut(df['LIMIT_BAL'], bins=4).value_counts()
# Out:
# (9010.0, 257500.0]       23282
# (257500.0, 505000.0]      6511
# (505000.0, 752500.0]       200
# (752500.0, 1000000.0]        6
# Name: LIMIT_BAL, dtype: int64

# %%
df = pd.get_dummies(df)

# %%
df = df.rename(columns = {"default payment next month_default": "Default","default payment next month_not default": "Not Default"})

# %%
df
# Out:
#        LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# 0          20000         1   24      2      2     -1     -1     -2     -2
# 1         120000         2   26     -1      2      0      0      0      2
# 2          90000         2   34      0      0      0      0      0      0
# 3          50000         1   37      0      0      0      0      0      0
# 4          50000         1   57     -1      0     -1      0      0      0
# ...          ...       ...  ...    ...    ...    ...    ...    ...    ...
# 29994     220000         1   39      0      0      0      0      0      0
# 29995     150000         2   43     -1     -1     -1     -1      0      0
# 29996      30000         2   37      4      3      2     -1      0      0
# 29997      80000         1   41      1     -1      0      0      0     -1
# 29998      50000         1   46      0      0      0      0      0      0
#
#        BILL_AMT1  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
df[['LIMIT_BAL','MARRIAGE','Default','Not Default']].groupby ('MARRIAGE'). mean()
# Out:
#               LIMIT_BAL   Default  Not Default
# MARRIAGE
# 0         132962.962963  0.092593     0.907407
# 1         182200.893184  0.234717     0.765283
# 2         156414.688968  0.209296     0.790704
# 3          98080.495356  0.260062     0.739938

# %%
df[['LIMIT_BAL','MARRIAGE','Default','Not Default']].groupby ('Default'). mean()
# Out:
#              LIMIT_BAL  MARRIAGE  Not Default
# Default
# 0        178101.356846  1.558618            1
# 1        130109.656420  1.528029            0

# %%
df[['LIMIT_BAL','MARRIAGE','Default','Not Default', 'EDUCATION_university','EDUCATION_high school','SEX_female','SEX_male']].groupby ('Default'). mean()
# Out:
#              LIMIT_BAL  MARRIAGE  Not Default  EDUCATION_university  \
# Default
# 0        178101.356846  1.558618          1.0              0.457989
# 1        130109.656420  1.528029          0.0              0.501808
#
#          EDUCATION_high school  SEX_female  SEX_male
# Default
# 0                     0.157514    0.614176  0.385824
# 1                     0.186407    0.567058  0.432942

# %%
df.describe()
# Out:
#             LIMIT_BAL      MARRIAGE           AGE         PAY_0         PAY_2  \
# count    29999.000000  29999.000000  29999.000000  29999.000000  29999.000000
# mean    167485.238841      1.551852     35.485650     -0.016701     -0.133771
# std     129749.727113      0.521972      9.218021      1.123820      1.197206
# min      10000.000000      0.000000     21.000000     -2.000000     -2.000000
# 25%      50000.000000      1.000000     28.000000     -1.000000     -1.000000
# 50%     140000.000000      2.000000     34.000000      0.000000      0.000000
# 75%     240000.000000      2.000000     41.000000      0.000000      0.000000
# max    1000000.000000      3.000000     79.000000      8.000000      8.000000
#
#               PAY_3         PAY_4         PAY_5         PAY_6      BILL_AMT1  \
# count  29999.000000  29999.000000  29999.000000  29999.000000   29999.000000
# mean      -0.166272     -0.220674     -0.266209     -0.291176   51224.134271
# ...

# %%
df_sample = df.sample(200)

# %%
x = df_sample['Default']
y = df_sample['LIMIT_BAL']

# %%
plt.scatter(x,y, marker='o')
plt.show()

# %%
x = df_sample['Not Default']
y = df_sample['LIMIT_BAL']

# %%
plt.scatter(x,y, marker='o')
plt.show()

# %%
x = df_sample['Default']
y = df_sample['SEX_male']

# %%
plt.scatter(x,y, marker='o')
plt.show()
